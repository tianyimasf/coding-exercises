# %% [markdown]
# <a href="https://www.kaggle.com/code/tianyimasf/life-story-eda-first-kaggle-notebook?scriptVersionId=105776118" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/life-story/datas.csv

# %%
df_train = pd.read_csv('../input/life-story/datas.csv')

# %% [markdown]
# # Basic Dataset Analysis

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2000 non-null   int64
#  1   id           2000 non-null   int64
#  2   age          2000 non-null   int64
#  3   sex          2000 non-null   object
#  4   eduLelev     1888 non-null   object
#  5   weight       2000 non-null   float64
#  6   occup        2000 non-null   object
#  7   qualif       1653 non-null   object
#  8   siblings     2000 non-null   int64
#  9   clso         2000 non-null   object
#  10  relig        2000 non-null   object
#  11  work.imp     1048 non-null   object
#  12  work.satisf  1048 non-null   object
#  13  hard.rock    2000 non-null   object
#  14  bd.reader    2000 non-null   object
#  15  fish.hunt    2000 non-null   object
#  16  cooking      2000 non-null   object
#  17  handyman     2000 non-null   object
# ...

# %% [markdown]
# #### clso = sense of belonging to a social class of individuals
# #### work.imp = Work importance
# #### bd.reader = Read Manga
# #### fish.hunt = Does Fishing or Hunting
# #### cinema = Goes to the Cinema or not
# #### hours.tv = Hours in Front of A TV

# %%
from IPython.display import display
temp = pd.DataFrame(df_train['age'].describe().astype('int'))

temp.style.set_properties(**{'border': '2px solid green',
                          'color': 'red'})
# Out:
# <style type="text/css">
# #T_8fdc8_row0_col0, #T_8fdc8_row1_col0, #T_8fdc8_row2_col0, #T_8fdc8_row3_col0, #T_8fdc8_row4_col0, #T_8fdc8_row5_col0, #T_8fdc8_row6_col0, #T_8fdc8_row7_col0 {
#   border: 2px solid green;
#   color: red;
# }
# </style>
# <table id="T_8fdc8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fdc8_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_8fdc8_row0_col0" class="data row0 col0" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_8fdc8_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_8fdc8_row1_col0" class="data row1 col0" >48</td>
#     </tr>
#     <tr>
#       <th id="T_8fdc8_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_8fdc8_row2_col0" class="data row2 col0" >16</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# #### Age Distribution

# %%
columns_to_include = ['hard.rock', 'bd.reader', 'fish.hunt', 'cooking', 'handyman', 'cinema', 'sport']
temp = pd.DataFrame();
for col in columns_to_include:
    distribution = df_train[col].value_counts(normalize=True) * 100
    temp[col] = distribution
temp
# Out:
#      hard.rock  bd.reader  fish.hunt  cooking  handyman  cinema  sport
# Non       99.3      97.65       88.8    55.95     57.35    58.7  63.85
# Oui        0.7       2.35       11.2    44.05     42.65    41.3  36.15

# %% [markdown]
# #### Answer distribution for each of the label

# %%
df_train['occup'].value_counts(normalize=True) * 100
# Out:
# Exerce une profession    52.45
# Retraite                 19.60
# Au foyer                  8.55
# Chomeur                   6.70
# Etudiant, eleve           4.70
# Autre inactif             4.15
# Retire des affaires       3.85
# Name: occup, dtype: float64

# %% [markdown]
# #### Possible values for column Occupation and percentage
# ##### Exerce une profession = Has a profession
# ##### Retraite = Retired
# ##### Au foyer = Home
# ##### Chomeur = Unemployed
# ##### Etudiant, eleve = Student, pupil
# ##### Autre inactif = Other Inactive
# ##### Retire des affaires = Out of Business

# %%
df_train['relig'].value_counts(normalize=True) * 100
# Out:
# Appartenance sans pratique     38.00
# Pratiquant occasionnel         22.10
# Ni croyance ni appartenance    19.95
# Pratiquant regulier            13.30
# Rejet                           4.65
# NSP ou NVPR                     2.00
# Name: relig, dtype: float64

# %% [markdown]
# #### Possible values for column Religion and percentage
# ##### Appartenance sans pratique = Membership Without Practice
# ##### Pratiquant occasionnel = Occasional Practitioner
# ##### Ni croyance ni appartenance = Neither believe or belong
# ##### Pratiquant regulier = Regular Practitioner
# ##### Rejet = Rejection
# ##### NSP ou NVPR = Don't know

# %%
df_train['sex'].value_counts(normalize=True) * 100
# Out:
# Femme    55.05
# Homme    44.95
# Name: sex, dtype: float64
